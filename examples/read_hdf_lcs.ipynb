# %%
import pandas as pd

# %%
phot = pd.read_hdf('MINION_DDF.hdf', 'photometry')

# %%
head = pd.read_hdf('MINION_DDF.hdf', 'summary')

# %%
head.head()
# Out:
#           IAUC  FAKE          RA       DECL  PIXSIZE  NXPIX  NYPIX  SNTYPE  \
# SNID
# 13    NULL         2    0.000000 -45.524532      0.2     -9     -9       1
# 31    NULL         2  150.362350   2.836485      0.2     -9     -9       1
# 42    NULL         2   34.393394  -5.090329      0.2     -9     -9       1
# 61    NULL         2  349.386444 -63.321003      0.2     -9     -9       1
# 89    NULL         2  150.362350   2.836485      0.2     -9     -9       1
#
#       NOBS  PTROBS_MIN      ...        SIM_EXPOSURE_r  SIM_EXPOSURE_i  \
# SNID                        ...
# 13      48           1      ...                   1.0             1.0
# 31      55          50      ...                   1.0             1.0
# 42      48         106      ...                   1.0             1.0
# 61      44         155      ...                   1.0             1.0
# 89      24         200      ...                   1.0             1.0
#
# ...

# %%
phot.head()
# Out:
#          MJD FLT         FIELD             TELESCOPE  PHOTFLAG  PHOTPROB  \
# 0  60902.180  r   NULL          LSST                         0       0.0
# 1  60902.195  i   NULL          LSST                         0       0.0
# 2  60902.203  z   NULL          LSST                         0       0.0
# 3  60902.215  Y   NULL          LSST                         0       0.0
# 4  60905.156  r   NULL          LSST                         0       0.0
#
#     FLUXCAL  FLUXCALERR         MAG     MAGERR  ...   PSF_SIG2  PSF_RATIO  \
# 0  0.151862    0.909222   29.546381  98.453621  ...        0.0        0.0
# 1  0.098467    1.485984   99.000000   5.000000  ...        0.0        0.0
# 2 -1.069675    2.108905  128.000000   0.000000  ...        0.0        0.0
# 3 -1.833690    7.798645  128.000000   0.000000  ...        0.0        0.0
# 4 -0.922795    1.159176  128.000000   0.000000  ...        0.0        0.0
#
#       SKY_SIG  SKY_SIG_T  RDNOISE     ZEROPT  ZEROPT_ERR  GAIN  SIM_MAGOBS  \
# ...

# %%
lcgroups = phot.groupby('SNID')

# %%
lcgroups.get_group(head.index[5999])
# Out:
#           MJD FLT         FIELD             TELESCOPE  PHOTFLAG  PHOTPROB  \
# 0   62600.020  r   NULL          LSST                         0       0.0
# 1   62600.035  i   NULL          LSST                         0       0.0
# 2   62600.047  z   NULL          LSST                         0       0.0
# 3   62600.059  Y   NULL          LSST                         0       0.0
# 4   62612.992  r   NULL          LSST                         0       0.0
# 5   62613.008  i   NULL          LSST                         0       0.0
# 6   62613.020  z   NULL          LSST                         0       0.0
# 7   62613.031  Y   NULL          LSST                         0       0.0
# 8   62615.992  r   NULL          LSST                         0       0.0
# 9   62616.008  i   NULL          LSST                         0       0.0
# 10  62616.016  z   NULL          LSST                         0       0.0
# 11  62616.027  Y   NULL          LSST                         0       0.0
# ...
